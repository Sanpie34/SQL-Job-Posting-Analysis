# %%
import numpy as np
import math
import pandas as pd
import json
import matplotlib.pyplot as plt
import os
import seaborn as sns

# %%
top_paying_jobs_DA = pd.read_csv(r"C:/Users/asus/Downloads/Programming and Data Analyst/SQL-Job-Posting-Analysis/SQL/sql_project/Data Analyst/CSV_result/1_top_paying_jobs_DA.csv")
top_paying_jobs_DS = pd.read_json(r"C:/Users/asus/Downloads/Programming and Data Analyst/SQL-Job-Posting-Analysis/SQL/sql_project/Data Scientist/JSON_result/1_top_paying_jobs_DS.json")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipython-input-664921199.py in <cell line: 0>()
# ----> 1 top_paying_jobs_DA = pd.read_csv(r"C:/Users/asus/Downloads/Programming and Data Analyst/SQL-Job-Posting-Analysis/SQL/sql_project/Data Analyst/CSV_result/1_top_paying_jobs_DA.csv")
#       2 top_paying_jobs_DS = pd.read_json(r"C:/Users/asus/Downloads/Programming and Data Analyst/SQL-Job-Posting-Analysis/SQL/sql_project/Data Scientist/JSON_result/1_top_paying_jobs_DS.json")
#
# ...

# %%
top_paying_jobs_DA
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-1335697707.py in <cell line: 0>()
# ----> 1 top_paying_jobs_DA
#
# NameError: name 'top_paying_jobs_DA' is not defined

# %%
top_paying_jobs_DS
# Out:
#     job_id                                          job_title job_location  \
# 0    40145              Staff Data Scientist/Quant Researcher     Anywhere
# 1  1714768          Staff Data Scientist - Business Analytics     Anywhere
# 2  1131472                                     Data Scientist     Anywhere
# 3  1742633                               Head of Data Science     Anywhere
# 4   551497                               Head of Data Science     Anywhere
# 5   126218  Director Level - Product Management - Data Sci...     Anywhere
# 6  1161630               Director of Data Science & Analytics     Anywhere
# 7   457991                       Head of Battery Data Science     Anywhere
# 8    38905                           Principal Data Scientist     Anywhere
# 9   226011                       Distinguished Data Scientist     Anywhere
#
#   job_schedule_type  salary_year_avg      job_posted_date        company_name
# ...

# %%
plt.figure(0, figsize=[12, 6])
plt.barh(top_paying_jobs_DA["job_title"], top_paying_jobs_DA["salary_year_avg"], label = "Dollar ($)", color = "brown")
plt.ylabel("Data Analyst Jobs")
plt.xlabel("Average Salary per Year")
plt.legend()
plt.title("Top Paying Jobs for Data Analyst")
plt.show()

plt.figure(0, figsize=[12, 6])
plt.barh(top_paying_jobs_DS["job_title"], top_paying_jobs_DS["salary_year_avg"], label = "Dollar ($)", color = "aqua")
plt.ylabel("Data Scientist Jobs")
plt.xlabel("Average Salary per Year")
plt.legend()
plt.title("Top Paying Jobs for Data Scientist")
plt.show()

# %%
top_paying_job_skills_DA = pd.read_json(r"C:\Users\asus\Downloads\Programming and Data Analyst\Data-Analyst-or-Data-Scientist-Portofolio\SQL\sql_project\Data Analyst\JSON_result\2_top_paying_job_skills_DA.json")
top_paying_job_skills_DS = pd.read_csv(r"C:\Users\asus\Downloads\Programming and Data Analyst\Data-Analyst-or-Data-Scientist-Portofolio\SQL\sql_project\Data Scientist\CSV_result\2_top_paying_job_skills_DS.csv")

# %%
top_paying_job_skills_DA
# Out:
#      job_id                          job_title  salary_year_avg  \
# 0    552322  Associate Director- Data Insights         255829.5
# 1    552322  Associate Director- Data Insights         255829.5
# 2    552322  Associate Director- Data Insights         255829.5
# 3    552322  Associate Director- Data Insights         255829.5
# 4    552322  Associate Director- Data Insights         255829.5
# ..      ...                                ...              ...
# 61  1749593             Principal Data Analyst         186000.0
# 62  1749593             Principal Data Analyst         186000.0
# 63   387860                   ERM Data Analyst         184000.0
# 64   387860                   ERM Data Analyst         184000.0
# 65   387860                   ERM Data Analyst         184000.0
#
#                                company_name      skills
# 0                                      AT&T         sql
# 1                                      AT&T      python
# ...

# %%
top_paying_job_skills_DS
# Out:
#      job_id                                          job_title  \
# 0     40145              Staff Data Scientist/Quant Researcher
# 1     40145              Staff Data Scientist/Quant Researcher
# 2   1714768          Staff Data Scientist - Business Analytics
# 3   1131472                                     Data Scientist
# 4   1131472                                     Data Scientist
# 5   1131472                                     Data Scientist
# 6   1131472                                     Data Scientist
# 7   1131472                                     Data Scientist
# 8   1131472                                     Data Scientist
# 9   1131472                                     Data Scientist
# 10   126218  Director Level - Product Management - Data Sci...
# 11   126218  Director Level - Product Management - Data Sci...
# 12   126218  Director Level - Product Management - Data Sci...
# 13   126218  Director Level - Product Management - Data Sci...
# ...

# %%
plt.figure(0, figsize=[12, 6])
plt.barh(top_paying_job_skills_DA["skills"][:5], top_paying_job_skills_DA["salary_year_avg"][:5], height = 0.4, label = "Dollar ($)", color = "green", align = "center")
plt.ylabel("Data Analyst Job Skills")
plt.xlabel("Average Salary per Year")
plt.legend()
plt.title("Top Paying Skills for Data Analyst")
plt.show()

plt.figure(0, figsize=[12, 6])
plt.barh(top_paying_job_skills_DS["skills"][:8], top_paying_job_skills_DS["salary_year_avg"][:8], height = 0.4, label = "Dollar ($)", color = "purple", align = "center")
plt.ylabel("Data Scientist Job Skills")
plt.xlabel("Average Salary per Year")
plt.legend()
plt.title("Top Paying Skills for Data Scientist")
plt.show()

# %%
top_demanded_skills_DA  = pd.read_csv(r"C:\Users\asus\Downloads\Programming and Data Analyst\Data-Analyst-or-Data-Scientist-Portofolio\SQL\sql_project\Data Analyst\CSV_result\3_top_demanded_skills_DA.csv")
top_demanded_skills_DS = pd.read_csv(r"C:\Users\asus\Downloads\Programming and Data Analyst\Data-Analyst-or-Data-Scientist-Portofolio\SQL\sql_project\Data Scientist\CSV_result\3_top_demanded_skills_DS.csv")

# %%
top_demanded_skills_DA
# Out:
#        skills  demand_count
# 0         sql          7346
# 1       excel          4638
# 2      python          4375
# 3     tableau          3772
# 4    power bi          2623
# 5           r          2163
# 6         sas          1878
# 7      looker           872
# 8       azure           827
# 9  powerpoint           823

# %%
top_demanded_skills_DS
# Out:
#        skills  demand_count
# 0      python         10443
# 1         sql          7520
# 2           r          4700
# 3         aws          2615
# 4     tableau          2465
# 5         sas          2220
# 6       spark          2021
# 7       azure          1928
# 8      pandas          1843
# 9  tensorflow          1840

# %%
plt.figure(0, figsize=[12, 6])
plt.bar(top_demanded_skills_DA["skills"], top_demanded_skills_DA["demand_count"], label = "Skill Job Counts", color = "magenta")
plt.xlabel("Data Analyst Job Skills")
plt.ylabel("Demand Count")
plt.legend()
plt.title("Top Demanded Skills for Data Analyst")
plt.show()

plt.figure(0, figsize=[12, 6])
plt.bar(top_demanded_skills_DS["skills"], top_demanded_skills_DS["demand_count"], label = "Skill Job Counts", color = "black")
plt.xlabel("Data Scientist Job Skills")
plt.ylabel("Demand Count")
plt.legend()
plt.title("Top Demanded Skills for Data Scientist")
plt.show()

# %%
top_paying_skills_DA = pd.read_json(r"C:\Users\asus\Downloads\Programming and Data Analyst\Data-Analyst-or-Data-Scientist-Portofolio\SQL\sql_project\Data Analyst\JSON_result\4_top_paying_skills_DA.json")
top_paying_skills_DS = pd.read_json(r"C:\Users\asus\Downloads\Programming and Data Analyst\Data-Analyst-or-Data-Scientist-Portofolio\SQL\sql_project\Data Scientist\JSON_result\4_top_paying_skills_DS.json")

# %%
top_paying_skills_DA
# Out:
#       skills  avg_salary
# 0        svn      400000
# 1   solidity      179000
# 2  couchbase      160515
# 3  datarobot      155486
# 4     golang      155000
# 5      mxnet      149000
# 6      dplyr      147633
# 7     vmware      147500
# 8  terraform      146734
# 9     twilio      138500

# %%
top_paying_skills_DS
# Out:
#           skills  avg_salary
# 0          asana      215477
# 1       airtable      201143
# 2         redhat      189500
# 3         watson      187417
# 4         elixir      170824
# 5            lua      170500
# 6          slack      168219
# 7       solidity      166980
# 8  ruby on rails      166500
# 9         rshiny      166436

# %%
plt.figure(0, figsize=[12, 6])
plt.bar(top_paying_skills_DA["skills"], top_paying_skills_DA["avg_salary"], color = "black")
plt.xlabel("Data Analyst Job Skills")
plt.ylabel("Average Salary")
plt.title("Top Paying Skills for Data Analyst")
plt.show()

plt.figure(0, figsize=[12, 6])
plt.bar(top_paying_skills_DS["skills"], top_paying_skills_DS["avg_salary"], color = "yellow")
plt.xlabel("Data Scientist Job Skills")
plt.ylabel("Average Salary")
plt.title("Top Paying Skills for Data Scientist")
plt.show()

# %%
optimal_skills_DA = pd.read_csv(r"C:\Users\asus\Downloads\Programming and Data Analyst\Data-Analyst-or-Data-Scientist-Portofolio\SQL\sql_project\Data Analyst\CSV_result\5_optimal_skills_DA.csv")
optimal_skills_DS = pd.read_csv(r"C:\Users\asus\Downloads\Programming and Data Analyst\Data-Analyst-or-Data-Scientist-Portofolio\SQL\sql_project\Data Scientist\CSV_result\5_optimal_skills_DS.csv")

# %%
optimal_skills_DA
# Out:
#    skill_id      skills  demand_count  salary_avg
# 0         0         sql           398       97237
# 1       181       excel           256       87288
# 2         1      python           236      101397
# 3       182     tableau           230       99288
# 4         5           r           148      100499
# 5       183    power bi           110       97431
# 6         7         sas            63       98902
# 7       186         sas            63       98902
# 8       196  powerpoint            58       88701
# 9       185      looker            49      103795

# %%
optimal_skills_DS
# Out:
#    skill_id      skills  demand_count  salary_avg
# 0         1      python           763      143828
# 1         0         sql           591      142833
# 2         5           r           394      137885
# 3       182     tableau           219      146970
# 4        76         aws           217      149630
# 5        92       spark           149      150188
# 6        99  tensorflow           126      151536
# 7        74       azure           122      142306
# 8       101     pytorch           115      152603
# 9        93      pandas           113      144816

# %%
plt.figure(0, figsize = [12,6])
plt.bar(optimal_skills_DA["skills"], optimal_skills_DA["salary_avg"], color = "brown")
plt.plot(optimal_skills_DA["skills"], optimal_skills_DA["demand_count"]*100, color = "purple", ls = "-", linewidth = 3, marker = "o", markersize = 10, label = "Demand Count (x100)")
plt.title("Optimal Skills for Data Analyst")
plt.xlabel("Skills")
plt.ylabel("Average Salary")
plt.legend()
plt.show()

plt.figure(0, figsize = [12,6])
plt.bar(optimal_skills_DS["skills"], optimal_skills_DS["salary_avg"], color = "brown")
plt.plot(optimal_skills_DS["skills"], optimal_skills_DS["demand_count"]*100, color = "purple", ls = "-", linewidth = 3, marker = "o", markersize = 10, label = "Demand Count (x100)")
plt.title("Optimal Skills for Data Scientist")
plt.xlabel("Skills")
plt.ylabel("Average Salary")
plt.legend()
plt.show()
